# %% [markdown]
# <a href="https://colab.research.google.com/github/Prajwal-Mohapatra/brain-tumor-unet/blob/main/brats_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip Brats_Scan.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Brats_Scan/Train-Val/BraTS-GLI-00421-000/BraTS-GLI-00421-000-t2w.jpg
#    creating: Brats_Scan/Train-Val/BraTS-GLI-00423-000/
#   inflating: Brats_Scan/Train-Val/BraTS-GLI-00423-000/BraTS-GLI-00423-000-seg.jpg
#   inflating: Brats_Scan/Train-Val/BraTS-GLI-00423-000/BraTS-GLI-00423-000-t1c.jpg
#   inflating: Brats_Scan/Train-Val/BraTS-GLI-00423-000/BraTS-GLI-00423-000-t1n.jpg
#   inflating: Brats_Scan/Train-Val/BraTS-GLI-00423-000/BraTS-GLI-00423-000-t2f.jpg
#   inflating: Brats_Scan/Train-Val/BraTS-GLI-00423-000/BraTS-GLI-00423-000-t2w.jpg
#    creating: Brats_Scan/Train-Val/BraTS-GLI-00425-000/
#   inflating: Brats_Scan/Train-Val/BraTS-GLI-00425-000/BraTS-GLI-00425-000-seg.jpg
#   inflating: Brats_Scan/Train-Val/BraTS-GLI-00425-000/BraTS-GLI-00425-000-t1c.jpg
#   inflating: Brats_Scan/Train-Val/BraTS-GLI-00425-000/BraTS-GLI-00425-000-t1n.jpg
# ...

# %%
# !unzip brats_pipeline.zip
# Out:
# Archive:  brats_pipeline.zip
#   inflating: evaluate.py
#   inflating: logger.py
#   inflating: losses.py
#   inflating: model.py
#   inflating: predict.py
#   inflating: requirements.txt
#   inflating: train.py
#   inflating: config.py
#   inflating: data.py
#   inflating: data_preprocess.py

# %%
#@title Load Dependencies
# !pip install -r requirements.txt --quiet

# %%
# !python config.py

# %%
# !python train.py
# Out:
# 2025-12-21 13:15:30.833051: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766322930.850860    1611 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766322930.856360    1611 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766322930.870139    1611 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python evaluate.py
# Out:
# 2025-12-21 13:37:31.492748: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766324251.511600    9626 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766324251.517217    9626 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766324251.531851    9626 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import os
from google.colab import files

# 1. Define your folder names (paths) here
folders_to_zip = "checkpoints logs results"
output_filename = "brats_v1_outputs.zip"

# 2. Run the zip command
# -r ensures it zips recursively (including subfolders/files)
# -q makes it 'quiet' (suppresses the long list of file output)
os.system(f"zip -r -q {output_filename} {folders_to_zip}")

# 3. Trigger the download
files.download(output_filename)
